# %% [markdown]
# https://docs.quiltdata.com/get-started/quick-start
#
# Make sure you `$ quilt login`

# %%
# !pip install quilt --upgrade

# %%
import sys
import pandas as pd
# %matplotlib inline

# %%
# Check we are using Python 3 in our kernel
print(sys.version)
# Out:
# 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
# !quilt install uciml/iris
# Out:
# ...
# 100%|██████████████████████████████████████| 23.5k/23.5k [00:02<00:00, 11.1kB/s]

# %%
from quilt.data.uciml import iris

# %%
iris
# Out:
# <GroupNode>
# raw/
# tables/
# README

# %%
iris.tables.iris().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tables.iris().plot();
