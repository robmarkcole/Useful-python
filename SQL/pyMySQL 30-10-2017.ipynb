# %% [markdown]
# https://community.home-assistant.io/t/setting-up-mysql-on-a-synology-nas-docker-container/16253/3
#
# http://nbviewer.jupyter.org/github/home-assistant/home-assistant-notebooks/tree/master/
#
# https://stackoverflow.com/questions/37730243/importing-data-from-a-mysql-database-into-a-pandas-data-frame-including-column-n
#
# https://github.com/PyMySQL/PyMySQL

# %%
import pymysql.cursors
import pandas as pd

# Connect to the database
connection = pymysql.connect(host='192.168.0.30',
                             user='hass',
                             password='12345',
                             db='homeassistant',
                             charset='utf8',  # 'utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

# %%
df = pd.read_sql('SELECT * FROM homeassistant.states', con=connection)

# %%
df
# Out:
#        state_id               domain                       entity_id  \
# 0             1                group              group.default_view
# 1             2                group   group.next_train_to_wim_group
# 2             3                group                group.traintimes
# 3             4                group                  group.controls
# 4             5                group                   group.weather
# 5             6                group                    group.travel
# 6             7                group                   group.sensors
# 7             8                group                    group.bme680
# 8             9                group                     group.blink
# 9            10                group                   group.cameras
# 10           11                group                   group.scripts
# 11           12                group                    group.family
# 12           13                group                       group.hue
# 13           14                  sun                         sun.sun
# 14           15                 zone                       zone.home
# 15           16                 zone                   zone.waterloo
# 16           17                 zone                    zone.redhill
# 17           18                 zone                       zone.work
# 18           19        binary_sensor   binary_sensor.in_bed_bayesian
# 19           20        binary_sensor    binary_sensor.motion_at_home
# 20           21  alarm_control_panel    alarm_control_panel.ha_alarm
# 21           22               sensor      sensor.bedroom_temperature
# 22           23               sensor        sensor.next_train_status
# 23           24               sensor  sensor.living_room_temperature
# 24           25               sensor              sensor.merton_pm10
# 25           26               sensor            sensor.next_train_in
# 26           27               sensor     sensor.next_train_scheduled
# 27           28               sensor         sensor.hall_temperature
# 28           29               sensor     sensor.next_train_estimated
# 29           30               sensor         sensor.mean_temperature
# ...         ...                  ...                             ...
# 9986       9987               sensor           sensor.bme680pressure
# 9987       9988               sensor           sensor.bme680air_qual
# 9988       9989               sensor        sensor.next_train_to_wim
# 9989       9990               sensor            sensor.next_train_in
# 9990       9991           automation  automation.train_state_trigger
# 9991       9992               sensor           sensor.bme680pressure
# 9992       9993               sensor           sensor.bme680air_qual
# 9993       9994               sensor           sensor.bme680air_qual
# 9994       9995               sensor           sensor.bme680humidity
# 9995       9996               sensor           sensor.bme680air_qual
# 9996       9997               sensor           sensor.bme680humidity
# 9997       9998               sensor           sensor.bme680pressure
# 9998       9999               sensor           sensor.bme680humidity
# 9999      10000               sensor           sensor.bme680pressure
# 10000     10001               sensor           sensor.bme680air_qual
# 10001     10002                  sun                         sun.sun
# 10002     10003               sensor           sensor.bme680humidity
# 10003     10004               sensor           sensor.bme680humidity
# 10004     10005               sensor           sensor.bme680pressure
# 10005     10006               sensor           sensor.bme680humidity
# 10006     10007               sensor        sensor.bme680temperature
# 10007     10008               sensor           sensor.bme680pressure
# 10008     10009               sensor           sensor.bme680humidity
# 10009     10010               sensor        sensor.bme680temperature
# 10010     10011               sensor           sensor.bme680pressure
# 10011     10012               sensor           sensor.bme680humidity
# 10012     10013               sensor           sensor.bme680pressure
# 10013     10014               sensor           sensor.bme680air_qual
# 10014     10015               sensor           sensor.bme680pressure
# 10015     10016               sensor           sensor.bme680air_qual
#
#                state                                         attributes  \
# 0            unknown  {"entity_id": ["device_tracker.robins_iphone",...
# 1            unknown  {"entity_id": ["sensor.next_train_to_wim"], "o...
# 2            unknown  {"entity_id": ["group.next_train_to_wim_group"...
# 3            unknown  {"entity_id": ["input_select.robin_loc_selecto...
# 4            unknown  {"entity_id": ["sensor.darksky_sensor_summary"...
# 5            unknown  {"entity_id": ["sensor.home_to_work", "sensor....
# 6            unknown  {"entity_id": ["sensor.time", "binary_sensor.b...
# 7            unknown  {"entity_id": ["sensor.bme680temperature", "se...
# 8            unknown  {"entity_id": ["sensor.blink_blink_camera_perc...
# 9            unknown  {"entity_id": ["camera.foscam_camera"], "order...
# 10           unknown  {"entity_id": ["script.activate_hue_remote_pyt...
# 11           unknown  {"entity_id": ["device_tracker.robins_iphone",...
# 12           unknown  {"entity_id": ["sensor.bedroom_motion_sensor",...
# 13     below_horizon  {"next_dawn": "2017-10-30T06:15:33+00:00", "ne...
# 14            zoning  {"hidden": true, "latitude": 51.383, "longitud...
# 15            zoning  {"hidden": true, "latitude": 51.5032, "longitu...
# 16            zoning  {"hidden": true, "latitude": 51.21, "longitude...
# 17            zoning  {"hidden": true, "latitude": 51.24, "longitude...
# 18               off  {"observations": [], "probability": 0.5, "prob...
# 19               off                {"friendly_name": "motion_at_home"}
# 20          disarmed  {"code_format": null, "changed_by": null, "fri...
# 21           unknown  {"unit_of_measurement": "\u00b0C", "friendly_n...
# 22           unknown             {"friendly_name": "Next train status"}
# 23           unknown  {"unit_of_measurement": "\u00b0C", "friendly_n...
# 24           unknown                   {"friendly_name": "Merton PM10"}
# 25           unknown                 {"friendly_name": "Next train in"}
# 26           unknown          {"friendly_name": "Next train scheduled"}
# 27           unknown  {"unit_of_measurement": "\u00b0C", "friendly_n...
# 28           unknown          {"friendly_name": "Next train estimated"}
# 29           unknown  {"count_sensors": 4, "max_value": "unknown", "...
# ...              ...                                                ...
# 9986         1033.99  {"unit_of_measurement": "hPa", "friendly_name"...
# 9987           97.61  {"unit_of_measurement": "%", "friendly_name": ...
# 9988              21  {"station_code": "MAL", "calling_at": "WIM", "...
# 9989           -39.0                 {"friendly_name": "Next train in"}
# 9990              on  {"last_triggered": "2017-10-30T07:23:23.840200...
# 9991          1034.0  {"unit_of_measurement": "hPa", "friendly_name"...
# 9992            97.6  {"unit_of_measurement": "%", "friendly_name": ...
# 9993           97.61  {"unit_of_measurement": "%", "friendly_name": ...
# 9994           45.76  {"unit_of_measurement": "%", "friendly_name": ...
# 9995            97.6  {"unit_of_measurement": "%", "friendly_name": ...
# 9996           45.75  {"unit_of_measurement": "%", "friendly_name": ...
# 9997         1033.99  {"unit_of_measurement": "hPa", "friendly_name"...
# 9998           45.74  {"unit_of_measurement": "%", "friendly_name": ...
# 9999         1033.98  {"unit_of_measurement": "hPa", "friendly_name"...
# 10000          97.61  {"unit_of_measurement": "%", "friendly_name": ...
# 10001  above_horizon  {"next_dawn": "2017-10-31T06:17:12+00:00", "ne...
# 10002          45.73  {"unit_of_measurement": "%", "friendly_name": ...
# 10003          45.75  {"unit_of_measurement": "%", "friendly_name": ...
# 10004        1033.99  {"unit_of_measurement": "hPa", "friendly_name"...
# 10005          45.74  {"unit_of_measurement": "%", "friendly_name": ...
# 10006          22.31  {"unit_of_measurement": "\u00b0C", "friendly_n...
# 10007        1033.98  {"unit_of_measurement": "hPa", "friendly_name"...
# 10008          45.73  {"unit_of_measurement": "%", "friendly_name": ...
# 10009          22.32  {"unit_of_measurement": "\u00b0C", "friendly_n...
# 10010        1033.99  {"unit_of_measurement": "hPa", "friendly_name"...
# 10011          45.75  {"unit_of_measurement": "%", "friendly_name": ...
# 10012        1033.98  {"unit_of_measurement": "hPa", "friendly_name"...
# 10013           97.6  {"unit_of_measurement": "%", "friendly_name": ...
# 10014        1033.99  {"unit_of_measurement": "hPa", "friendly_name"...
# 10015          97.61  {"unit_of_measurement": "%", "friendly_name": ...
#
#       event_id        last_changed        last_updated             created
# 0         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 1         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 2         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 3         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 4         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 5         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 6         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 7         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 8         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 9         None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 10        None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 11        None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 12        None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 13        None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 14        None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 15        None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 16        None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 17        None 2017-10-30 05:45:59 2017-10-30 05:45:59 2017-10-30 05:46:27
# 18        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 19        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 20        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 21        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 22        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 23        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 24        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 25        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 26        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 27        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 28        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
# 29        None 2017-10-30 05:46:00 2017-10-30 05:46:00 2017-10-30 05:46:28
