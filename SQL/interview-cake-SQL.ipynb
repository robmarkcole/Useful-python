# %% [markdown]
# Exercises from https://www.interviewcake.com/article/python/sql uses MySQL
#
# To start the server and logon as root
# ```
# mysql.server start && mysql -u root
# ```
#
# ```sql
# USE BAKERY;
# ```
#
# I am working through the excercises at the terminal but lets also work along using pandas
#
# Found a nice GUI tool https://github.com/sequelpro/sequelpro just point to localhost and user `root`

# %%
from IPython.display import Image
Image("sequelpro.png", width=500)

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

user = 'root'
ip = 'localhost'
db = 'bakery'
engine = create_engine(f'mysql+pymysql://{user}@{ip}/{db}?charset=utf8', echo=False)

# %%
pd.read_sql("show tables;", con=engine)
# Out:
#         Tables_in_bakery
# 0                  cakes
# 1  customer_order_counts
# 2              customers
# 3                 orders

# %% [markdown]
# We can see the top 10 entries, using sql
# ```sql
# select * from bakery.orders limit 10;
# ```

# %%
# %%time
sql = "select * from bakery.orders limit 10;"
df = pd.read_sql(sql, con=engine)
# Out:
# CPU times: user 3.36 ms, sys: 1.23 ms, total: 4.58 ms
# Wall time: 8.8 ms

# %%
df
# Out:
#    order_id  cake_id customer_id pickup_date
# 0         1        2        None  2017-01-08
# 1         2        1        None  2017-09-17
# 2         3        3        None  2017-07-19
# 3         4        2        None  2017-12-03
# 4         5        2        None  2017-08-20
# 5         6        3        None  2017-04-10
# 6         7        3        None  2017-10-03
# 7         8        3        None  2017-08-08
# 8         9        3        None  2017-12-11
# 9        10        2        None  2017-12-10
