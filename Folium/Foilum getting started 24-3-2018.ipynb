# %% [markdown]
# https://folium.readthedocs.io/en/latest/
#
# Folium makes it easy to visualize data that’s been manipulated in Python on an interactive Leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing Vincent/Vega visualizations as markers on the map.

# %%
import folium
from folium.plugins import HeatMap
import os
import numpy as np

lat = 51.383578
long = -0.262539
zoom = 14

# %%
map_osm = folium.Map(location=[lat, long], zoom_start=zoom)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm.save('map.html')

# %%
data = (np.random.normal(scale=0.05, size=(100, 3)) *
        np.array([[1, 1, 1]]) +
        np.array([[lat, long, 1]])).tolist()

# %%
data[:10] # Data is imaginary lat long and reading
# Out:
# [[51.45002750657269, -0.17519229881614234, 0.924975927473958],
#  [51.3362458181619, -0.3033702315672328, 0.9818837515201658],
#  [51.44660687331623, -0.17086290901979273, 1.0802539103470832],
#  [51.370830088312594, -0.2937248425708477, 1.0428370783940861],
#  [51.35833904445555, -0.3743262346727481, 1.024360746173159],
#  [51.387527537733426, -0.1728509113883826, 0.9567920451457917],
#  [51.3367608541036, -0.22638487985503372, 1.0058020624895685],
#  [51.396014832055414, -0.21011745150434624, 1.0001077317499845],
#  [51.38345766084217, -0.2287749684239176, 1.0501908562888487],
#  [51.36831178665079, -0.24730034295488112, 1.1648600428011224]]

# %%
m = folium.Map([lat, long],  zoom_start=zoom) # tiles='stamentoner',

HeatMap(data).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('Heatmap.html')
