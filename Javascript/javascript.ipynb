// %% [markdown]
// https://github.com/n-riesco/ijavascript

// %%
var msg = ["Hello", "World!"].join(", ");

// %%
msg
// Out:
// 'Hello, World!'

// %%
console.log(msg);
// Out:
// Hello, World!

// %%
console.error(msg);
// Out:
// Hello, World!

// %%
throw new Error("Oh noes!");
// Out:
// evalmachine.<anonymous>:1
// throw new Error("Oh noes!");
// ^
//
// Error: Oh noes!
//     at evalmachine.<anonymous>:1:7
//     at ContextifyScript.Script.runInThisContext (vm.js:25:33)
//     at Object.runInThisContext (vm.js:97:38)
//     at run ([eval]:1002:15)
//     at onRunRequest ([eval]:829:18)
//     at onMessage ([eval]:789:13)
//     at emitTwo (events.js:106:13)
//     at process.emit (events.js:191:7)
//     at process.nextTick (internal/child_process.js:758:12)
//     at _combinedTickCallback (internal/process/next_tick.js:73:7)

// %%
var data = [];
for (var i = 0; i < 1000; i++) {
    var x = 2*Math.PI * i/ 360;
    var obj = {
      x: x,
      i: i,
      sin: Math.sin(x),
      cos: Math.cos(x),
      tan: Math.tan(x)
    };
    data.push(obj);
}
// Out:
// 1000

// %%
data
// Out:
// [ { x: 0, i: 0, sin: 0, cos: 1, tan: 0 },
//   { x: 0.017453292519943295,
//     i: 1,
//     sin: 0.01745240643728351,
//     cos: 0.9998476951563913,
//     tan: 0.017455064928217585 },
//   { x: 0.03490658503988659,
//     i: 2,
//     sin: 0.03489949670250097,
//     cos: 0.9993908270190958,
//     tan: 0.03492076949174773 },
//   { x: 0.05235987755982988,
//     i: 3,
//     sin: 0.05233595624294383,
//     cos: 0.9986295347545738,
//     tan: 0.0524077792830412 },
//   { x: 0.06981317007977318,
//     i: 4,
//     sin: 0.0697564737441253,
//     cos: 0.9975640502598242,
//     tan: 0.06992681194351041 },
//   { x: 0.08726646259971647,
//     i: 5,
//     sin: 0.08715574274765817,
//     cos: 0.9961946980917455,
//     tan: 0.08748866352592401 },
//   { x: 0.10471975511965977,
//     i: 6,
//     sin: 0.10452846326765346,
//     cos: 0.9945218953682733,
//     tan: 0.10510423526567646 },
//   { x: 0.12217304763960307,
//     i: 7,
//     sin: 0.12186934340514748,
// ...

// %% [markdown]
// Not sure if plotting is supported
