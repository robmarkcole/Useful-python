# %% [markdown]
# https://mpld3.github.io/quickstart.html sadly no longer maintained and only compatible with py 34

# %%
import matplotlib.pyplot as plt, mpld3
plt.plot([3,1,4,1,5], 'ks-', mec='w', mew=5, ms=20)
mpld3.show()
# Out:
# Note: if you're in the IPython notebook, mpld3.show() is not the best command
#       to use. Consider using mpld3.display(), or mpld3.enable_notebook().
#       See more information at http://mpld3.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8891/    [Ctrl-C to exit]
# 127.0.0.1 - - [02/Mar/2018 14:47:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Mar/2018 14:47:46] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Mar/2018 14:47:46] "GET /mpld3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Mar/2018 14:47:46] code 404, message Not Found
# 127.0.0.1 - - [02/Mar/2018 14:47:46] "GET /favicon.ico HTTP/1.1" 404 -
# stopping Server...
