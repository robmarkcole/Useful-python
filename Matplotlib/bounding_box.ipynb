# %% [markdown]
# matplotlib uses pillow for opening images

# %%
# !wget https://www.google.com/url?sa=i&url=https%3A%2F%2Fmatplotlib.org%2F3.1.1%2Ftutorials%2Fintroductory%2Fimages.html&psig=AOvVaw3FtX0735Nn0ckAlJLcUR-W&ust=1607921400453000&source=images&cd=vfe&ved=0CAIQjRxqFwoTCNDhjJGUyu0CFQAAAAAdAAAAABAI

# %%
ls /home/jovyan/work/Matplotlib
# Out:
# '3d line plot.ipynb'                    imshow.ipynb
#  animation/                             layer_images.ipynb
#  annotation_basic.ipynb                 line.gif
#  autoscale.ipynb                        linestyles.ipynb
#  axes_demo.ipynb                        mandelbrot-animated.gif
#  barplot-simple.ipynb                  'Plot and scatter.ipynb'
#  bayes_update_sgskip.ipynb              README.md
#  bounding_box.ipynb                    'Real time plotting 2-11-2017.ipynb'
#  collections.ipynb                      stinkbug.png
# 'Compare PDD 3-3-2017.ipynb'           'sub plots.ipynb'
#  dynamic_image.ipynb                    test.mp4
#  dynamic_images.mp4                     timeline.ipynb
# 'Fill plots.ipynb'                     'To html'/
# 'Filtering home-assistant data.ipynb'   topographic_hillshading.ipynb

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

# %%
pwd
# Out:
# '/home/jovyan'

# %%
im = np.array(Image.open('/home/jovyan/work/Matplotlib/stinkbug.png'), dtype=np.uint8)

# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# Create a Rectangle patch
rect = patches.Rectangle((50,100),40,30,linewidth=1,edgecolor='r',facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()
