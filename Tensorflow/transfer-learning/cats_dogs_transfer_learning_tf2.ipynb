# %% [markdown]
# https://keras.io/guides/transfer_learning/
#
# An end-to-end example: fine-tuning an image classification model on a cats vs. dogs
#
# dataset
#
# To solidify these concepts, let's walk you through a concrete end-to-end transfer learning & fine-tuning example. We will load the Xception model, pre-trained on ImageNet, and use it on the Kaggle "cats vs. dogs" classification dataset.

# %%
# !pip install tf-nightly-gpu
# Out:
# Collecting tf-nightly-gpu
#   Downloading https://files.pythonhosted.org/packages/dd/6d/f71e6ad70430c0c203591c33b2975dd0ca051b0497e2b23d79406c739bf5/tf_nightly_gpu-2.3.0.dev20200615-cp36-cp36m-manylinux2010_x86_64.whl (350.2MB)
#      |████████████████████████████████| 350.2MB 26kB/s
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (1.4.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (1.29.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (0.34.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (1.12.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (0.3.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (3.2.1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (1.6.3)
# Collecting tf-estimator-nightly
#   Downloading https://files.pythonhosted.org/packages/fe/e1/337e99c3a46c3066c6678b0193c634d30df8adaade24a009f00b1a8eca41/tf_estimator_nightly-2.3.0.dev2020061501-py2.py3-none-any.whl (459kB)
#      |████████████████████████████████| 460kB 46.7MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (0.9.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (3.10.0)
# Collecting tb-nightly<2.4.0a0,>=2.3.0a0
#   Downloading https://files.pythonhosted.org/packages/7f/15/4ae5c16903f0b3ed5569b3cd214175aa29be786eadd4c531f77fa553c88f/tb_nightly-2.3.0a20200615-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 46.1MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (1.12.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (1.18.5)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-gpu) (1.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tf-nightly-gpu) (47.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.6.0.post3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.7.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (3.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.3.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (0.2.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (2.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (3.1.0)
# Installing collected packages: tf-estimator-nightly, tb-nightly, tf-nightly-gpu
# Successfully installed tb-nightly-2.3.0a20200615 tf-estimator-nightly-2.3.0.dev2020061501 tf-nightly-gpu-2.3.0.dev20200615

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.3.0-dev20200615'

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow_datasets as tfds

tfds.disable_progress_bar()

train_ds, validation_ds, test_ds = tfds.load(
    "cats_vs_dogs",
    # Reserve 10% for validation and 10% for test
    split=["train[:40%]", "train[40%:50%]", "train[50%:60%]"],
    as_supervised=True,  # Include labels
)

print("Number of training samples: %d" % tf.data.experimental.cardinality(train_ds))
print(
    "Number of validation samples: %d" % tf.data.experimental.cardinality(validation_ds)
)
print("Number of test samples: %d" % tf.data.experimental.cardinality(test_ds))
# Out:
# Downloading and preparing dataset cats_vs_dogs/4.0.0 (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /root/tensorflow_datasets/cats_vs_dogs/4.0.0...
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling and writing examples to /root/tensorflow_datasets/cats_vs_dogs/4.0.0.incomplete7NPT7T/cats_vs_dogs-train.tfrecord
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.
# Number of training samples: -2
# Number of validation samples: -2
# Number of test samples: -2

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for i, (image, label) in enumerate(train_ds.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image)
    plt.title(int(label))
    plt.axis("off")

# %%
size = (150, 150)

train_ds = train_ds.map(lambda x, y: (tf.image.resize(x, size), y))
validation_ds = validation_ds.map(lambda x, y: (tf.image.resize(x, size), y))
test_ds = test_ds.map(lambda x, y: (tf.image.resize(x, size), y))

# %%
batch_size = 32

train_ds = train_ds.cache().batch(batch_size).prefetch(buffer_size=10)
validation_ds = validation_ds.cache().batch(batch_size).prefetch(buffer_size=10)
test_ds = test_ds.cache().batch(batch_size).prefetch(buffer_size=10)

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
    ]
)

# %%
import numpy as np

for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    first_image = images[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(
            tf.expand_dims(first_image, 0), training=True
        )
        plt.imshow(augmented_image[0].numpy().astype("int32"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
base_model = keras.applications.Xception(
    weights="imagenet",  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False,
)  # Do not include the ImageNet classifier at the top.

# Freeze the base_model
base_model.trainable = False

# Create new model on top
inputs = keras.Input(shape=(150, 150, 3))
x = data_augmentation(inputs)  # Apply random data augmentation

# Pre-trained Xception weights requires that input be normalized
# from (0, 255) to a range (-1., +1.), the normalization layer
# does the following, outputs = (inputs - mean) / sqrt(var)
norm_layer = keras.layers.experimental.preprocessing.Normalization()
mean = np.array([127.5] * 3)
var = mean ** 2
# Scale inputs to [-1, +1]
x = norm_layer(x)
norm_layer.set_weights([mean, var])

# The base model contains batchnorm layers. We want to keep them in inference mode
# when we unfreeze the base model for fine-tuning, so we make sure that the
# base_model is running in inference mode here.
x = base_model(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = keras.layers.Dense(1)(x)
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 150, 150, 3)       0
# _________________________________________________________________
# normalization (Normalization (None, 150, 150, 3)       7
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 20,863,536
# Trainable params: 2,049
# Non-trainable params: 20,861,487
# _________________________________________________________________

# %% [markdown]
# Train the top layer

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

epochs = 20
model.fit(train_ds, epochs=epochs, validation_data=validation_ds)
# Out:
# Epoch 1/20
# 291/291 [==============================] - 32s 108ms/step - loss: 0.1682 - binary_accuracy: 0.9263 - val_loss: 0.0875 - val_binary_accuracy: 0.9721
# Epoch 2/20
# 291/291 [==============================] - 27s 91ms/step - loss: 0.1199 - binary_accuracy: 0.9465 - val_loss: 0.0801 - val_binary_accuracy: 0.9716
# Epoch 3/20
# 291/291 [==============================] - 27s 91ms/step - loss: 0.1181 - binary_accuracy: 0.9520 - val_loss: 0.0820 - val_binary_accuracy: 0.9695
# Epoch 4/20
# 291/291 [==============================] - 27s 92ms/step - loss: 0.1069 - binary_accuracy: 0.9548 - val_loss: 0.0859 - val_binary_accuracy: 0.9678
# Epoch 5/20
# 291/291 [==============================] - 26s 91ms/step - loss: 0.1024 - binary_accuracy: 0.9560 - val_loss: 0.0831 - val_binary_accuracy: 0.9695
# Epoch 6/20
# 291/291 [==============================] - 26s 91ms/step - loss: 0.1044 - binary_accuracy: 0.9546 - val_loss: 0.0856 - val_binary_accuracy: 0.9695
# Epoch 7/20
# 291/291 [==============================] - 26s 91ms/step - loss: 0.1004 - binary_accuracy: 0.9606 - val_loss: 0.0797 - val_binary_accuracy: 0.9699
# Epoch 8/20
# 291/291 [==============================] - 27s 91ms/step - loss: 0.0972 - binary_accuracy: 0.9600 - val_loss: 0.0780 - val_binary_accuracy: 0.9703
# Epoch 9/20
# 291/291 [==============================] - 26s 91ms/step - loss: 0.0968 - binary_accuracy: 0.9620 - val_loss: 0.0806 - val_binary_accuracy: 0.9699
# Epoch 10/20
# 291/291 [==============================] - 26s 91ms/step - loss: 0.1005 - binary_accuracy: 0.9597 - val_loss: 0.0793 - val_binary_accuracy: 0.9712
# Epoch 11/20
# 291/291 [==============================] - 26s 91ms/step - loss: 0.0884 - binary_accuracy: 0.9630 - val_loss: 0.0789 - val_binary_accuracy: 0.9686
# Epoch 12/20
# 291/291 [==============================] - 26s 91ms/step - loss: 0.0980 - binary_accuracy: 0.9615 - val_loss: 0.0741 - val_binary_accuracy: 0.9716
# Epoch 13/20
# 291/291 [==============================] - 27s 91ms/step - loss: 0.0945 - binary_accuracy: 0.9596 - val_loss: 0.0769 - val_binary_accuracy: 0.9716
# Epoch 14/20
# 291/291 [==============================] - 26s 91ms/step - loss: 0.1001 - binary_accuracy: 0.9557 - val_loss: 0.0782 - val_binary_accuracy: 0.9703
# Epoch 15/20
# 291/291 [==============================] - 27s 91ms/step - loss: 0.0966 - binary_accuracy: 0.9595 - val_loss: 0.0805 - val_binary_accuracy: 0.9690
# Epoch 16/20
# 291/291 [==============================] - 27s 92ms/step - loss: 0.0918 - binary_accuracy: 0.9614 - val_loss: 0.0837 - val_binary_accuracy: 0.9690
# Epoch 17/20
# 291/291 [==============================] - 27s 92ms/step - loss: 0.1025 - binary_accuracy: 0.9584 - val_loss: 0.0827 - val_binary_accuracy: 0.9686
# Epoch 18/20
# 291/291 [==============================] - 27s 92ms/step - loss: 0.0960 - binary_accuracy: 0.9610 - val_loss: 0.0790 - val_binary_accuracy: 0.9703
# Epoch 19/20
# 291/291 [==============================] - 26s 91ms/step - loss: 0.0920 - binary_accuracy: 0.9629 - val_loss: 0.0818 - val_binary_accuracy: 0.9682
# Epoch 20/20
# 291/291 [==============================] - 27s 91ms/step - loss: 0.0945 - binary_accuracy: 0.9610 - val_loss: 0.0795 - val_binary_accuracy: 0.9682

# %% [markdown]
# Do a round of fine-tuning of the entire model
#
# Finally, let's unfreeze the base model and train the entire model end-to-end with a low learning rate.

# %%
# Unfreeze the base_model. Note that it keeps running in inference mode
# since we passed `training=False` when calling it. This means that
# the batchnorm layers will not update their batch statistics.
# This prevents the batchnorm layers from undoing all the training
# we've done so far.
base_model.trainable = True
model.summary()

model.compile(
    optimizer=keras.optimizers.Adam(1e-5),  # Low learning rate
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

epochs = 10
model.fit(train_ds, epochs=epochs, validation_data=validation_ds)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 150, 150, 3)       0
# _________________________________________________________________
# normalization (Normalization (None, 150, 150, 3)       7
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 20,863,536
# Trainable params: 20,809,001
# Non-trainable params: 54,535
# _________________________________________________________________
# Epoch 1/10
#       2/Unknown - 0s 182ms/step - loss: 0.1009 - binary_accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0968s vs `on_train_batch_end` time: 0.2675s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0968s vs `on_train_batch_end` time: 0.2675s). Check your callbacks.
# 291/291 [==============================] - 110s 377ms/step - loss: 0.0818 - binary_accuracy: 0.9684 - val_loss: 0.0523 - val_binary_accuracy: 0.9772
# Epoch 2/10
# 291/291 [==============================] - 109s 374ms/step - loss: 0.0558 - binary_accuracy: 0.9785 - val_loss: 0.0520 - val_binary_accuracy: 0.9785
# Epoch 3/10
# 291/291 [==============================] - 108s 372ms/step - loss: 0.0412 - binary_accuracy: 0.9852 - val_loss: 0.0492 - val_binary_accuracy: 0.9785
# Epoch 4/10
# 291/291 [==============================] - 108s 372ms/step - loss: 0.0408 - binary_accuracy: 0.9841 - val_loss: 0.0459 - val_binary_accuracy: 0.9802
# Epoch 5/10
# 291/291 [==============================] - 113s 388ms/step - loss: 0.0333 - binary_accuracy: 0.9879 - val_loss: 0.0475 - val_binary_accuracy: 0.9832
# Epoch 6/10
# 291/291 [==============================] - 108s 371ms/step - loss: 0.0231 - binary_accuracy: 0.9925 - val_loss: 0.0452 - val_binary_accuracy: 0.9837
# Epoch 7/10
# 291/291 [==============================] - 109s 373ms/step - loss: 0.0212 - binary_accuracy: 0.9920 - val_loss: 0.0490 - val_binary_accuracy: 0.9837
# Epoch 8/10
# 291/291 [==============================] - 109s 373ms/step - loss: 0.0184 - binary_accuracy: 0.9930 - val_loss: 0.0461 - val_binary_accuracy: 0.9845
# Epoch 9/10
# 291/291 [==============================] - 109s 375ms/step - loss: 0.0168 - binary_accuracy: 0.9938 - val_loss: 0.0546 - val_binary_accuracy: 0.9841
# Epoch 10/10
# 291/291 [==============================] - 111s 383ms/step - loss: 0.0155 - binary_accuracy: 0.9951 - val_loss: 0.0490 - val_binary_accuracy: 0.9845

# %% [markdown]
# We have improved accuracy
