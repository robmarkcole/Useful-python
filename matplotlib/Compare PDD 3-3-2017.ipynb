# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
files = os.listdir()

# %%
files[1]
# Out:
# 'AAA_PDD_DoseProfile.txt'

# %%
files[2]
# Out:
# 'AXB_PDD_DoseProfile.txt'

# %%
AAA_df = pd.read_table(files[1], skiprows=11, index_col=0, header=None, names=['PDD'])
AAA_df = 100.0*AAA_df/AAA_df.max()   # normalise

AXB_df = pd.read_table(files[2], skiprows=11, index_col=0, header=None, names=['PDD'])
AXB_df = 100.0*AXB_df/AXB_df.max()   # normalise

# %%
data_df = pd.concat([AAA_df, AXB_df],axis=1)
data_df.head()
# Out:
#                 PDD        PDD
# 0.000000   0.000000  27.192201
# 0.025014   0.000000  31.673650
# 0.050028   0.000000  36.155098
# 0.075042   0.000000  40.636547
# 0.100057  43.906084  45.117995

# %%
height=4
width=12           # wwidth of figs
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(width, height))

ax1.plot(AAA_df, label = 'AAA', c='r')
ax1.plot(AXB_df, label = 'AXB', linestyle='--')
ax1.legend()
ax1.set_xlabel('Depth (cm)')
ax1.set_ylabel('PDD (%)')

ax2.plot(AAA_df-AXB_df, label = 'AAA - AXB')
ax2.set_ylim([-2,2])
ax2.set_xlabel('Depth (cm)')
ax2.set_ylabel('PDD difference AAA - AXB (%)')

plt.show()
