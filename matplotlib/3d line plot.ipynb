# %% [markdown]
# https://www.getdatajoy.com/learn/3D_Plots_With_Matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
#%matplotlib inline 
# %matplotlib notebook

# %% [markdown]
# # Basic line plot

# %%
theta = np.linspace(-9 * np.pi, 9 * np.pi, 300)
s = 3*np.cos(theta)
t = 3*np.sin(theta)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(s, t, theta)
 
ax.view_init(elev=20, azim=60)
ax.dist = 11
plt.show()
# Out:
# <div id='7b5631e2-19d0-4e8b-894e-8d4d395a97cc'></div>

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pickle as pk
import numpy as np

plt.ioff()

t = np.linspace(0, 6*np.pi, 1000)
x = np.sin(t)
y = np.cos(t)
z = t/100

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, label='3d plot')
plt.show()
