# %% [markdown]
# http://scikit-image.org/

# %%
from skimage import data, io, filters
image = data.coins()  # an ndarray
edges = filters.sobel(image)
io.imshow(edges)
io.show()

# %%
# ?filters.sobel
