# %% [markdown]
# https://pythonbasics.org/webserver/
#
# Run a basic webserver that list files in directory

# %%
# !python3 -m http.server
# Out:
# Serving HTTP on 0.0.0.0 port 8000 (http://0.0.0.0:8000/) ...
# 127.0.0.1 - - [12/Jul/2019 06:09:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jul/2019 06:09:37] code 404, message File not found
# 127.0.0.1 - - [12/Jul/2019 06:09:37] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from IPython.display import Image
Image("basic_webserver.png", width=400)

# %% [markdown]
# ## Official docs
# https://docs.python.org/3/library/http.server.html
