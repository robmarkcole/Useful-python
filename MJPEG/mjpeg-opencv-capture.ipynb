# %%
MJPEG_URL = "http://127.0.0.1:8080/cam.mjpg" # from the streamer code

# %%
import cv2

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.1.0'

# %%
# %%time
vidcap = cv2.VideoCapture(MJPEG_URL)

# %%
success,image = vidcap.read()

# %%
success
# Out:
# True

# %%
type(image)
# Out:
# numpy.ndarray

# %%
plt.imshow(image);

# %% [markdown]
# hmm colours are distorted
