# %% [markdown]
# https://docs.djangoproject.com/en/1.10/intro/tutorial01/
#
# Cells starting with $ are entered into the shell

# %%
import django
from IPython.display import Image

# %%
print(django.get_version())
# Out:
# 1.10.5

# %% [markdown]
# $ django-admin startproject mysite

# %% [markdown]
# Creates the project, consisting of a folder and several python files

# %% [markdown]
# Run the server, now viewable at http://127.0.0.1:8000/

# %% [markdown]
# $ python manage.py runserver

# %%
Image("welcome.PNG")  # this is what you see

# %% [markdown]
# HERE
#
# https://docs.djangoproject.com/en/1.10/intro/tutorial01/#creating-the-polls-app
