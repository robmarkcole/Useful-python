# %%
from pandas.io.data import DataReader
from datetime import datetime
# %matplotlib inline

ibm = DataReader('IBM',  'yahoo', datetime(2000, 1, 1), datetime(2012, 1, 1))
ibm.head()
# Out:
#                 Open      High      Low     Close    Volume  Adj Close
# Date
# 2000-01-03  112.4375  116.0000  111.875  116.0000  10347700  88.455060
# 2000-01-04  114.0000  114.5000  110.875  112.0625   8227800  85.452544
# 2000-01-05  112.9375  119.7500  112.125  116.0000  12733200  88.455060
# 2000-01-06  118.0000  118.9375  113.500  114.0000   7971900  86.929973
# 2000-01-07  117.2500  117.9375  110.625  113.5000  11856700  86.548701

# %%
ibm.plot()
