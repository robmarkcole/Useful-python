# %% [markdown]
# https://blog.machinebox.io/introducing-objectbox-super-simple-object-detection-90699b92738d TLDR `Objectbox is 100% trainable.`
#
# Pull and run box with:
# ```
# export MB_OBJECTBOX_BOXDATA=`pwd`/boxdata
#
# sudo docker run -p 8080:8080 -e "MB_KEY=$MB_KEY" -e "MB_OBJECTBOX_ANNOTATION_TOOL=true" -v $MB_OBJECTBOX_BOXDATA:/boxdata machinebox/objectbox
# ```
#
# * Designate a folder on your hard drive for the videos and images you want to use for training
# * With the box running head to [http://localhost:8080/](http://localhost:8080/)

# %%
boxdata = "/Users/robincole/machinebox/boxdata"

# %% [markdown]
# Place some photos in `boxdata/files`

# %%
from IPython.display import Image
Image("objectbox_files.png", width=800)

# %%
Image("objectbox_annotation.png", width=800)

# %% [markdown]
# Post a test image

# %%
Image("test_bird.jpg", width=400)

# %%
# !curl -X POST -F 'file=@test_bird.jpg' http://localhost:8080/objectbox/check
# Out:
# {
# 	"success": true,
# 	"detectors": [
# 		{
# 			"id": "bird",
# 			"name": "bird",
# 			"objects": null
# 		},
# 		{
# 			"id": "feeder",
# 			"name": "feeder",
# 			"objects": [
# 				{
# 					"rect": {
# 						"top": 27,
# 						"left": 134,
# 						"width": 321,
# 						"height": 321
# 					},
# 					"score": 0.4341146693400523
# 				}
# 			]
# 		}
# 	]
# }
