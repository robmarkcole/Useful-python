# %% [markdown]
# http://pythonhosted.org/imreg_dft/quickstart.html#quickstart
#
# http://pythonhosted.org//imreg_dft/

# %%
import os
import scipy as sp
import scipy.misc
import imreg_dft as ird
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
im0 = sp.misc.imread("Clin.png")
# the image to be transformed
im1 = sp.misc.imread("True.png")
#plt.imshow(im0)  # scales added by import

# %%
im0.shape
# Out:
# (529, 796, 4)

# %%
im1.shape
# Out:
# (471, 1072, 4)

# %%
im1_resized = sp.misc.imresize(im1, im0.shape)   # make same shape

# %%
plt.imshow(im1_resized)

# %%
# result = ird.similarity(im0, im1_resized, numiter=3)

# %%
level = 2
arr0 = np.array(im0)[:,:,level]  # get the red channel
arr1 = np.array(im1_resized)[:,:,level]  # get the red channel

# %%
plt.imshow(arr0)

# %%
sharpened = im.filter(ImageFilter.SHARPEN)

# %%
plt.imshow(arr1)

# %%
result = ird.similarity(arr0, arr1, numiter=3)
# Out:
# C:\Users\RCole02.ROYALSURREY\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\ndimage\interpolation.py:568: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)

# %%
ird.imshow(arr0, arr1, result['timg'])
