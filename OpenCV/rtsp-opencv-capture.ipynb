# %%
USERNAME = "admin"
PASSWORD = "pass"
RTSP_URL = f"rtsp://{USERNAME}:{PASSWORD}@192.168.1.221:554/11"

# %%
import cv2

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '3.4.2'

# %%
vidcap = cv2.VideoCapture(RTSP_URL)

# %%
success,image = vidcap.read()

# %%
success
# Out:
# True

# %%
type(image)
# Out:
# numpy.ndarray

# %%
plt.imshow(image)

# %% [markdown]
# hmm colours are distorted
