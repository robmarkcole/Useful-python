# %%
USERNAME = "admin"
PASSWORD = "Highcloud1"
RTSP_URL = f"rtsp://{USERNAME}:{PASSWORD}@192.168.1.94:554/11"
print(RTSP_URL)
    
# MJPEG_URL = "http://127.0.0.1:8080/cam.mjpg"
# Out:
# rtsp://admin:Highcloud1@192.168.1.94:554/11

# %%
import cv2

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.1.0'

# %%
# %%time
vidcap = cv2.VideoCapture(RTSP_URL)
# vidcap = cv2.VideoCapture(MJPEG_URL)
# Out:
# CPU times: user 42.6 ms, sys: 38.7 ms, total: 81.3 ms
# Wall time: 1.96 s

# %%
success,image = vidcap.read()

# %%
success
# Out:
# True

# %%
type(image)
# Out:
# numpy.ndarray

# %%
plt.imshow(image);

# %% [markdown]
# hmm colours are distorted - [needs to be set](https://www.learnopencv.com/why-does-opencv-use-bgr-color-format/) in RGB for display
