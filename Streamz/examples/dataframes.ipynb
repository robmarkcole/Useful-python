# %%
from streamz.dataframe import Random, DataFrame

# %%
source = Random(freq='5ms', interval='100ms')
source.x.sum()
# Out:
# Output()

# %%
sdf = (source - 0.5).cumsum()
sdf.tail()
# Out:
# Output()

# %%
p = (DataFrame({'raw': sdf.x,
                        'smooth': sdf.x.rolling('100ms').mean(),
                        'very-smooth': sdf.x.rolling('500ms').mean()})
     .plot(width=700)
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-744383deadb7> in <module>()
#       1 p = (DataFrame({'raw': sdf.x,
#       2                         'smooth': sdf.x.rolling('100ms').mean(),
# ----> 3                         'very-smooth': sdf.x.rolling('500ms').mean()})
#       4      .plot(width=700)
#       5     )
#
# ~/anaconda3/lib/python3.6/site-packages/streamz/dataframe/core.py in __getattr__(self, key)
#     205             return self.map_partitions(getattr, self, key)
#     206         else:
# --> 207             raise AttributeError("DataFrame has no attribute %r" % key)
#     208
#     209     def __dir__(self):
#
# AttributeError: DataFrame has no attribute 'plot'
